# %% [markdown]
# ### 🧪 Revisão de prova - Missão: Condicionais 🤖
#
# Você está sendo avaliado(a) em sua habilidade de tomar decisões automatizadas por meio de códigos. Em cada uma das atividades a seguir, use estruturas condicionais com sabedoria.

# %% [markdown]
# ### ⚖️ Desafio 01 - Avaliação de Desempenho na Agência 🧾 (Usando if, múltiplos elif e else)

# %% [markdown]
# O Sistema de Avaliação da Agência Central de Inteligência precisa classificar os agentes de acordo com sua nota final. Sua missão é automatizar esse processo.

# %% [markdown]
# 🎯 Objetivo:
# Solicitar o nome do agente e sua nota final (0 a 10).
# Exibir a classificação:

# %% [markdown]
# Solicitar o nome do agente e sua nota final (0 a 10).
# Exibir a classificação:
#
# Nota	Classificação
#
# 9.0 a 10.0	Excelente 🏅
#
# 7.0 a 8.9	Bom     print("bom")
#
#
# 5.0 a 6.9	Regular
#
# 3.0 a 4.9	Ruim 🚫
#
# 0.0 a 2.9	Crítico 🚨
# Fora do intervalo
# Nota inválida ❌

# %% [markdown]
# Exibir mensagem:
# "Agente [NOME], sua classificação é: [classificação] (nota: [nota])"

# %% [markdown]
# 📦 Instruções Gerais
#
# Mantenha seu código indentado corretamente e com prints claros.
# Personalize a saída sempre que possível usando o nome do usuário.

# %% [markdown]
# Boa sorte nas decisões lógicas, agente.
# A sua capacidade de condicionar pode alterar o curso do código.

# %% [markdown]
# ### Desempenho da Agencia

# %%
nome = input("digite seu nome :") #aqui criamos uma variável e pedimos um nome ao usuário
nota= float(input("qual a sua nota?")) #aqui criamos uma variável que pergunta a nota do usuário

if nota >=9 and nota<=10:   # "Se" a nota for maior igual a 9 e menor igual a 10, a classificação do usuário será excelente.
    print(f" Agente {nome}, sua classificação é :excelente🎆,nota:{nota}")

elif nota >=7 and nota <=8.9:  # "senão se" a nota for maior igual a 7 e menor igual a 8.9, a classificação do usuário será boa.
    print(f" Agente {nome}, sua classificação é :boa 👌, nota {nota}") 

elif nota >=5 and nota <=6.9:  # "senão se " a nota for maior igual a 5 e menor igual a 6.9, a classificação do usuário será regular
    print(f"Agente {nome}, sua classificação é : regular😒, nota {nota}")

elif nota >=3 and nota <=4.9: # "senão se" a nota for maior igual a 3 e menor igual a 4.9, a classificação do usuário será ruim.
    print(f"Agente {nome}, sua classificação é : ruim🚫, nota {nota}")

elif nota >=0.0 and nota <=2.9:
    print(f"Agente {nome}, sua classificação é : crítico🚨, nota {nota}")

else:
    print("Nota inválida ❌")
# Out:
# Nota inválida ❌
